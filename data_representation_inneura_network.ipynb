# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
ka=np.array([1,2,3])
print(ka)
# Out:
# [1 2 3]

# %%
kh=np.array(12)

# %%
kh.ndim
# Out:
# 0

# %%
one_dim=np.array([1,2,3])
one_dim.ndim
# Out:
# 1

# %%
mat_dim=np.array([[1,2,3],[4,5,6]])
mat_dim.shape
# Out:
# (2, 3)

# %%
mat_dim.ndim
# Out:
# 2

# %%
one_dim.shape
# Out:
# (3,)

# %% [markdown]
# #### Now On Tensorflow

# %%
import tensorflow as tf

gh=tf.constant([1,2,3])
print(gh)
# Out:
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)

# %%
var = tf.Variable([[3, 2],
                 [5, 2],
                 [5, 2]])

# %%
var
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[3, 2],
#        [5, 2],
#        [5, 2]], dtype=int32)>

# %%
tf.shape(var)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
from tensorflow import keras

# %%
fashom_mnist=keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)=fashom_mnist.load_data()
print(train_images.shape)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# (60000, 28, 28)

# %%
train_images_one=train_images[0]

# %%
train_images[0]
plt.imshow(train_images[0])
